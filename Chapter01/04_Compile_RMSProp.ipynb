# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow import keras

# %%
EPOCHS = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2
DROPOUT = 0.3
RESHAPED = 784

# %%
mnist = keras.datasets.mnist

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(-1, RESHAPED) / 255.
X_test = X_test.reshape(-1, RESHAPED) / 255.

# %%
Y_train = keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = keras.utils.to_categorical(Y_test, NB_CLASSES)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED, ), activation = 'relu'),
    keras.layers.Dropout(DROPOUT),
    keras.layers.Dense(N_HIDDEN, activation='relu'),
    keras.layers.Dropout(DROPOUT),
    keras.layers.Dense(NB_CLASSES, activation='softmax')
])

# %%
model.compile(optimizer="RMSProp", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=VALIDATION_SPLIT, verbose = VERBOSE)
# Out:
# Epoch 1/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4803 - accuracy: 0.8563 - val_loss: 0.1788 - val_accuracy: 0.9477
# Epoch 2/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9338 - val_loss: 0.1322 - val_accuracy: 0.9613
# Epoch 3/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1722 - accuracy: 0.9491 - val_loss: 0.1176 - val_accuracy: 0.9657
# Epoch 4/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1448 - accuracy: 0.9570 - val_loss: 0.1024 - val_accuracy: 0.9702
# Epoch 5/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1265 - accuracy: 0.9621 - val_loss: 0.1068 - val_accuracy: 0.9714
# Epoch 6/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1153 - accuracy: 0.9652 - val_loss: 0.1051 - val_accuracy: 0.9722
# Epoch 7/200
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 757us/step - loss: 0.2968 - accuracy: 0.9791
# Test accuracy: 0.9790999889373779
